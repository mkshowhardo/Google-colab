# %% [markdown]
# <a href="https://colab.research.google.com/github/mkshowhardo/Google-colab/blob/main/column_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('covid_toy.csv')

# %%
df.head(5)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)

# %%
x_train
# Out:
#     age  gender  fever   cough       city
# 6    14    Male  101.0  Strong  Bangalore
# 92   82  Female  102.0  Strong    Kolkata
# 62   56  Female  104.0  Strong  Bangalore
# 44   20    Male  102.0  Strong      Delhi
# 53   83    Male   98.0    Mild      Delhi
# ..  ...     ...    ...     ...        ...
# 73   34    Male   98.0  Strong    Kolkata
# 8    19  Female  100.0  Strong  Bangalore
# 25   23    Male    NaN    Mild     Mumbai
# 42   27    Male  100.0    Mild      Delhi
# 94   79    Male    NaN  Strong    Kolkata
#
# [80 rows x 5 columns]

# %%
si = SimpleImputer()

x_train_fever = si.fit_transform(x_train[['fever']])
x_test_fever = si.fit_transform(x_test[['fever']])

# %%
x_train_fever
# Out:
# array([[101.        ],
#        [102.        ],
#        [104.        ],
#        [102.        ],
#        [ 98.        ],
#        [104.        ],
#        [104.        ],
#        [ 98.        ],
#        [104.        ],
#        [101.        ],
#        [102.        ],
#        [104.        ],
#        [101.        ],
#        [102.        ],
#        [100.        ],
#        [ 99.        ],
#        [100.78378378],
#        [101.        ],
#        [101.        ],
#        [103.        ],
#        [ 98.        ],
#        [100.78378378],
#        [100.        ],
#        [103.        ],
#        [103.        ],
#        [100.        ],
#        [ 99.        ],
#        [100.        ],
#        [104.        ],
#        [104.        ],
#        [100.        ],
#        [101.        ],
#        [101.        ],
#        [ 99.        ],
#        [102.        ],
#        [ 98.        ],
#        [101.        ],
#        [100.78378378],
#        [ 98.        ],
#        [103.        ],
# ...

# %%
oe = OrdinalEncoder(categories=[['Mild','Strong']])

x_train_cough = oe.fit_transform(x_train[['cough']])
x_test_cough = oe.fit_transform(x_test[['cough']])

# %%
x_train_cough.shape
# Out:
# (80, 1)

# %%
ohe = OneHotEncoder(drop = 'first', sparse_output= False)

x_train_gender_city = ohe.fit_transform(x_train[['gender','city']])
x_test_gender_city = ohe.fit_transform(x_test[['gender', 'city']])

# %%
x_train_gender_city.shape
# Out:
# (80, 4)

# %%
x_train_age = x_train.drop(columns=['gender','fever','cough','city']).values
x_test_age = x_train.drop(columns=['gender','fever','cough','city']).values

# %%
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_age = np.array(x_train_age)
x_train_cough = np.array(x_train_cough)
x_train_gender_city = np.array(x_train_gender_city)
x_train_fever = np.array(x_train_fever)

x_train_transformed = np.concatenate(('x_train_age','x_train_cough','x_train_gender_city','x_train_fever'),axis =0)
x_test_transformed = np.concatenate(('x_test_age','x_test_cough','x_test_gender_city','x_test_fever'),axis =0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-4975624056b4> in <cell line: 6>()
#       4 x_train_fever = np.array(x_train_fever)
#       5
# ----> 6 x_train_transformed = np.concatenate(('x_train_age','x_train_cough','x_train_gender_city','x_train_fever'),axis =0)
#       7 x_test_transformed = np.concatenate(('x_test_age','x_test_cough','x_test_gender_city','x_test_fever'),axis =0)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1', SimpleImputer(),['fever']),
    ('tnf2', OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3', OneHotEncoder(drop = 'first',sparse_output = False),['gender','city'])
],remainder='passthrough')

# %%
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('tnf1', SimpleImputer(), ['fever']),
#                                 ('tnf2',
#                                  OrdinalEncoder(categories=[['Mild',
#                                                              'Strong']]),
#                                  ['cough']),
#                                 ('tnf3',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['gender', 'city'])])

# %%
transformer.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
transformer.fit_transform(x_test).shape
# Out:
# (20, 7)

# %%
transformer = ColumnTransformer(transformers =[
    ('tnf1', SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild', 'Strong']]),['cough']),
    ('tnf3',OneHotEncoder(drop='first', sparse_output= False),['gender','city'])
], remainder = 'passthrough')
